# %%
import numpy

# %%
import matplotlib.pyplot as plt

# %%
costhetaL=numpy.load('costhetaL.npy')

# %%
costhetaR=numpy.load('costhetaR.npy')

# %%
plt.hist(costhetaL, histtype="step", label="left")
plt.hist(costhetaR, histtype="step", label="right")
plt.title("Left vs Right Handed cos(theta)")
plt.xlabel("x")
plt.ylabel("hits")
plt.legend()
plt.show()
